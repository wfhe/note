# %%
import numpy as np
from sklearn.svm import SVR
import matplotlib.pyplot as plt

# %%
# 生成样本数据
X = np.sort(5 * np.random.rand(40, 1), axis=0)
y = np.ravel(2*X + 3)# 把多维数组降低为1维

# %%
# 加入部分噪音
y[::5] += 3 * (0.5 - np.random.rand(8)) #每隔5个数加上一个数
# Out:
# array([ 2.30511429,  0.11523039,  0.37294754,  0.56655931,  0.60949187,
#         0.09114815,  0.81386561,  0.83155456,  0.97988868,  0.99818397,
#         2.4943782 ,  0.99535909,  0.99462557,  0.94469242,  0.90264364,
#         0.77124969,  0.89137788,  0.84782921,  0.81971081,  0.62045709,
#         1.62521771,  0.08938365,  0.07239914, -0.08097748, -0.20346608,
#         0.32406778, -0.28812975, -0.30593632, -0.3247473 , -0.36551861,
#         1.37636336, -0.47792728, -0.75036397, -0.78410746, -0.83212187,
#         0.96965465, -0.86622205, -0.99369388, -0.99845742, -0.98174624])

# %%
# 调用模型
svr_rbf = SVR(kernel='rbf', C=1e3, gamma=0.1)
svr_lin = SVR(kernel='linear', C=1e3)
svr_poly = SVR(kernel='poly', C=1e3, degree=2)
y_rbf = svr_rbf.fit(X, y).predict(X)
y_lin = svr_lin.fit(X, y).predict(X)
y_poly = svr_poly.fit(X, y).predict(X)
# Out:
# d:\python\envs\test1\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)

# %%
# 可视化结果
lw = 2
plt.scatter(X, y, color='darkorange', label='data')#散点图
plt.plot(X, y_rbf, color='navy', lw=lw, label='RBF model')
plt.plot(X, y_lin, color='c', lw=lw, label='Linear model')
plt.plot(X, y_poly, color='cornflowerblue', lw=lw, label='Polynomial model')
plt.xlabel('data')
plt.ylabel('target')
plt.title('Support Vector Regression')
plt.legend()
plt.show()

# %%
y = np.polyval([2,3,5,2], X).ravel() # 多项式求值

y[::5] += 3 * (0.5 - np.random.rand(8))
# 调用模型
svr_rbf = SVR(kernel='rbf', C=1e3, gamma=0.1)
svr_lin = SVR(kernel='linear', C=1e3)
svr_poly = SVR(kernel='poly', C=1e3, degree=2)
y_rbf = svr_rbf.fit(X, y).predict(X)
y_lin = svr_lin.fit(X, y).predict(X)
y_poly = svr_poly.fit(X, y).predict(X)
# 可视化结果
lw = 2
plt.scatter(X, y, color='darkorange', label='data')
plt.plot(X, y_rbf, color='navy', lw=lw, label='RBF model')
plt.plot(X, y_lin, color='c', lw=lw, label='Linear model')
plt.plot(X, y_poly, color='cornflowerblue', lw=lw, label='Polynomial model')
plt.xlabel('data')
plt.ylabel('target')
plt.title('Support Vector Regression')
plt.legend()
plt.show()
# Out:
# d:\python\envs\test1\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
